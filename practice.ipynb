# %%
import requests
from bs4 import BeautifulSoup
import re

res =requests.get("http://davelee-fun.github.io/blog/crawl_test")
soup = BeautifulSoup(res.content, 'html.parser')

section = soup.find('ul', id='dev_course_list')
titles = section.find_all('li','course')
for title in titles:
    print(re.sub('\[[0-9]+\]','',title.get_text()))
# Out:
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개
# (초급) - 필요한 프로그램 설치 시연
# (초급) - 데이터를 엑셀 파일로 만들기
# (초급) -     엑셀 파일 이쁘게! 이쁘게!
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기

# %%
import requests
from bs4 import BeautifulSoup

res =requests.get("http://davelee-fun.github.io/blog/crawl_test")
soup = BeautifulSoup(res.content, 'html.parser')

section = soup.find('ul', id='dev_course_list')
titles = section.find_all('li','course')
for idx,title in enumerate(titles):
    print(idx ,title.get_text().split('[')[0].split('-')[1])
# Out:
# 0  강사가 실제 사용하는 자동 프로그램 소개
# 1  필요한 프로그램 설치 시연
# 2  데이터를 엑셀 파일로 만들기
# 3      엑셀 파일 이쁘게! 이쁘게!
# 4      나대신 주기적으로 파이썬 프로그램 실행하기
# 5  파이썬으로 슬랙(slack) 메신저에 글쓰기
# 6  웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
# 7  네이버 API 사용해서, 블로그에 글쓰기
# 8  자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기

# %%
import requests
from bs4 import BeautifulSoup

res =requests.get("http://davelee-fun.github.io/")
soup = BeautifulSoup(res.content, 'html.parser')

titles = soup.select("tr")

for idx,title in enumerate(titles):
    col = title.select('td')
    row=''
    for c in col:
        row += c.get_text()
    print(row)
# Out:
# 일정커리큘럼 타이틀난이도
# 5.1 ~ 6.15나만의 엣지있는 블로그 사이트 만들기 (취미로 익히는 IT)초급
# 6.16 ~ 7.31파이썬과 데이터과학 첫걸음 (IT 기본기 익히기)중급

# %%
import requests
from bs4 import BeautifulSoup
url = "https://davelee-fun.github.io/page"
for i in range(1,7):
    ress = requests.get(url + str(i))
    
    soup = BeautifulSoup(ress.content,'html.parser')
    data = soup.find_all('h4','card-text')
    for d in data:
        print(d)
# Out:
# <h4 class="card-text">상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
#
# </h4>
# <h4 class="card-text">상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
#
# </h4>
# <h4 class="card-text">상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트
#
# </h4>
# <h4 class="card-text">상품명: 프랑떼 항균 방수 매트리스커버, 화이트
#
# </h4>
# <h4 class="card-text">상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
#
# </h4>
# <h4 class="card-text">상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
#
# </h4>
# <h4 class="card-text">상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
#
# </h4>
# <h4 class="card-text">상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
#
# </h4>
# <h4 class="card-text">상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
#
# </h4>
# <h4 class="card-text">상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트
#
# </h4>
# <h4 class="card-text">상품명: 피아블 클래식 방수 매트리스커버, 화이트
#
# </h4>
# <h4 class="card-text">상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
#
# </h4>
# <h4 class="card-text">상품명: 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
#
# </h4>
# <h4 class="card-text">상품명: 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
#
# </h4>
# <h4 class="card-text">상품명: 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
#
# ...

# %%
import openpyxl

# %%
def write_excel(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width=100
    excel_sheet.column_dimensions['B'].width=50
    excel_sheet.column_dimensions['B'].height=50
   
    
    if sheetname != '':
        excel_sheet.title = sheetname
    for item in listdata:
        excel_sheet.append(item)
    excel_file.save(filename)
    excel_file.close()

# %%
product_lists = list()

for page_num in range(10):
    if page_num == 0:
        res = requests.get('http://davelee-fun.github.io/')
    else:
        res = requests.get('http://davelee-fun.github.io/page'+str(page_num+1))
        
    soup = BeautifulSoup(res.content,'html.parser')
    data= soup.select('div.card')
    for item in data:
        product_name = item.select_one('div.card-body h4.card-text')
        product_date = item.select_one('div.wrapfooter span.post-date')
        product_info = [product_name.get_text().strip(), product_date.get_text()]
        product_lists.append(product_info)

# %%
write_excel('tmp1.xlsx','상품정보',product_lists)

# %%
import openpyxl

excel_file = openpyxl.load_workbook('tmp1.xlsx')

excel_file.sheetnames
# Out:
# ['상품정보']

# %%
excel_s = excel_file['상품정보']

# %%
for item in excel_s.rows:
    print(item[0].value, item[1].value)
# Out:
#   Cell In[1], line 2
#     print(item[0].value, item[1].value).
#                                         ^
# SyntaxError: invalid syntax

# %%
import requests
import pprint
client_id = 'p2g7WObW6P8NB3wGpv7D'
client_secret = 'dL3cw1xlyF'

naver_openapi = 'https://openapi.naver.com/v1/search/news.json?query=android'
header_params= {'X-Naver-Client-Id':client_id , 'X-Naver-Client-Secret':client_secret}

res = requests.get(naver_openapi, headers = header_params)

if res.status_code == 200:
    data = res.json()
    for idx,i in enumerate(data['items']):
        print('title : ',i['title'],'\n','link : ' ,i['link'])
else:
    print("Error Code : ", res.status_code)
# Out:
# title :  [Herald Interview] UK firm lures Korean trendsetters with &apos;transparent p...
#  link :  https://n.news.naver.com/mnews/article/044/0000248203?sid=104
# title :  [크립토리뷰] 라분 얼라이언스, 하이프랩스와 파트너십 체결(7월2주차)
#  link :  https://www.theguru.co.kr/news/article.html?no=56815
# title :  Hackers steal W8m from Starbucks app
#  link :  https://n.news.naver.com/mnews/article/044/0000248160?sid=104
# title :  스마트폰 교체형 배터리 의무화 임박…삼성·애플·구글 영향은?
#  link :  http://www.digitaltoday.co.kr/news/articleView.html?idxno=481874
# title :  Pokémon Korea &apos;Pokémon Sleep&apos; 신규 정보 공개
#  link :  http://gamefocus.co.kr/detail.php?number=143080
# title :  Starbucks Korea says hackers stole 8 million won from 90 clients
#  link :  https://n.news.naver.com/mnews/article/640/0000040764?sid=101
# title :  &apos;Pokémon Sleep(포켓몬 슬립)&apos;, 7월 하순부터 순차적으로 서비스 시작 예정
#  link :  https://www.gamechosun.co.kr/webzine/article/view.php?no=197200
# title :  코로나19 덕에 날개 달았던 명품 플랫폼 3사, 수익성 ‘추락’
# ...

# %%
import requests
import openpyxl
import pprint
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width=100
excel_sheet.column_dimensions['C'].width=100
excel_sheet.append(['랭킹','제목','링크'])

num = 0
client_id = 'p2g7WObW6P8NB3wGpv7D'
client_secret = 'dL3cw1xlyF'

start =1
for a in range(10):
    start_number=start+(a*100)
    naver_openapi = 'https://openapi.naver.com/v1/search/shop.json?query=샤오미&display=100&start=' + str(start_number)
    header_params= {'X-Naver-Client-Id':client_id , 'X-Naver-Client-Secret':client_secret}
 
    res = requests.get(naver_openapi, headers = header_params)

    if res.status_code == 200:
        data = res.json()
        pprint.pprint(data)
        for i in data['items']:
            num +=1
            excel_sheet.append([num,i['title'],i['link']])
    else:
        print("Error Code : ", res.status_code)
excel_file.save('샤오밍.xlsx')
excel_file.close()
# Out:
# {'display': 100,
#  'items': [{'brand': '샤오미',
#             'category1': '디지털/가전',
#             'category2': '휴대폰액세서리',
#             'category3': '휴대폰배터리',
#             'category4': '보조배터리',
#             'hprice': '',
#             'image': 'https://shopping-phinf.pstatic.net/main_8517598/85175988630.4.jpg',
#             'link': 'https://search.shopping.naver.com/gate.nhn?id=85175988630',
#             'lprice': '15900',
#             'maker': '샤오미',
#             'mallName': '조아 마켓',
#             'productId': '85175988630',
#             'productType': '2',
#             'title': '<b>샤오미</b>보조배터리 10000 초고속 충전 7세대 미니 휴대폰 C타입 갤럭시 아이폰'},
#            {'brand': '샤오미',
#             'category1': '디지털/가전',
#             'category2': '휴대폰액세서리',
#             'category3': '휴대폰배터리',
#             'category4': '보조배터리',
#             'hprice': '',
#             'image': 'https://shopping-phinf.pstatic.net/main_8524015/85240159154.8.jpg',
# ...

# %%
import requests

url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMinuDustFrcstDspth?'
params ={'serviceKey' : 'zQPvp8ey6v330Sp%2FQuT3nVLb0fIhX8%2BpFzzuuNP9fMBVFL9h0%2FX5vpBPzne8BF4Fk0niTzAy55MN%2Bnnnlkv24A%3D%3D', 'returnType' : 'xml', 'numOfRows' : '100', 'pageNo' : '1', 'searchDate' : '2020-11-14', 'InformCode' : 'PM10' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMinuDustFrcstDspth?serviceKey=zQPvp8ey6v330Sp%2FQuT3nVLb0fIhX8%2BpFzzuuNP9fMBVFL9h0%2FX5vpBPzne8BF4Fk0niTzAy55MN%2Bnnnlkv24A%3D%3D&returnType=xml&numOfRows=100&pageNo=1&searchDate=2020-11-14&InformCode=PM10
# Out:
#   Cell In[34], line 1
#     http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMinuDustFrcstDspth?serviceKey=zQPvp8ey6v330Sp%2FQuT3nVLb0fIhX8%2BpFzzuuNP9fMBVFL9h0%2FX5vpBPzne8BF4Fk0niTzAy55MN%2Bnnnlkv24A%3D%3D&returnType=xml&numOfRows=100&pageNo=1&searchDate=2020-11-14&InformCode=PM10
#                                                                                                          ^
# SyntaxError: invalid decimal literal

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://davelee-fun.github.io/blog/crawling_stock_example.html'

res = requests.get(url)

soup =  BeautifulSoup(res.content , 'html.parser')
y=''
data = soup.find_all('li','row_sty')

for i in data:
    a= i.find('div','st_name').get_text().replace(' ','').replace('\n','')
    b=i.find('div','st_price').get_text().replace(' ','').replace('\n','')
    c=i.find('div','st_rate').get_text().replace(' ','').replace('\n','')
    y= a+' '+b+' '+c
    print(y)
# Out:
# CJ씨푸드 3,705 -0.94%
# CJ씨푸드1우 25,300 0.20%
# CJ제일제당 321,500 -0.77%
# CJ제일제당우 150,300 0.20%
# MH에탄올 7,580 0.00%
# SPC삼립 74,400 -1.06%
# 고려산업 4,505 1.81%
# 남양유업 504,000 -0.20%
# 남양유업우 286,500 0.88%
# 농심 448,000 -0.88%
# 대상 18,910 -1.51%
# 대상우 15,350 -0.39%
# 대한제당 3,735 2.89%
# 대한제당우 3,225 3.53%
# 대한제분 138,500 -0.93%
# 동원F&B 31,950 -1.54%
# 롯데제과 110,500 0.18%
# 롯데칠성 139,900 -0.71%
# 롯데칠성우 67,400 0.00%
# 마니커 1,467 -0.81%
# 무학 5,700 -1.04%
# 보해양조 609 1.00%
# 빙그레 49,150 0.72%
# 사조대림 29,350 -0.34%
# 사조동아원 1,134 0.71%
# 사조씨푸드 5,750 -0.69%
# 사조오양 8,410 -2.77%
# 삼양사 45,200 2.03%
# 삼양사우 28,150 0.36%
# 삼양식품 120,000 -0.83%
# 샘표식품 29,250 0.17%
# 서울식품 222 -0.45%
# 서울식품우 2,400 -2.04%
# 선진 9,270 0.98%
# 오뚜기 452,000 -0.99%
# 오리온 125,100 -0.08%
# 우성 25,150 -0.98%
# 조흥 208,000 0.00%
# 크라운제과 9,040 -0.88%
# 크라운제과우 11,120 -0.71%
# 팜스코 4,840 1.57%
# 풀무원 11,370 -1.04%
# 하이트진로 22,650 1.12%
# 하이트진로2우B 16,550 0.36%
# 한성기업 6,010 -0.83%
# 해태제과식품 6,090 -0.98%
# BYC 416,000 -0.48%
# BYC우 150,000 0.00%
# ...

# %%
y ='a'

for i in ['b','c']:
    y+=i
    print(y)
print(y)
# Out:
# ab
# abc
# abc
