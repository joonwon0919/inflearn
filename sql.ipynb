# %%
# 1. 라이브러리 가져오기
import pymysql

# 2. 접속하기
db = pymysql.connect(
    host='localhost', 
    port=3306, 
    user='root', 
    passwd='djaakWkd1!', 
    db='ecommerce', 
    charset='utf8')

# 3. 커서 가져오기
cursor = db.cursor()

# 4. SQL 구문 만들기 (CRUD SQL 구문 등)
sql = '''
    CREATE TABLE product (
        PRODUCT_CODE VARCHAR(20) NOT NULL,
        TITLE VARCHAR(200) NOT NULL,
        ORI_PRICE INT,
        DISCOUNT_PRICE INT,
        DISCOUNT_PERCENT INT,
        DELIVERY VARCHAR(2),
        PRIMARY KEY(PRODUCT_CODE)
    );
'''

# 5. SQL 구문 실행하기
cursor.execute(sql)

# 6. DB에 Complete 하기
db.commit()

# 7. DB 연결 닫기
db.close()

# %%
# 1. 라이브러리 가져오기
import pymysql

# 2. 접속하기
db = pymysql.connect(
    host='localhost', 
    port=3306, 
    user='root', 
    passwd='djaakWkd1!', 
    db='ecommerce', 
    charset='utf8')

# 3. 커서 가져오기
cursor = db.cursor()
sql= '''update product set
    title = '기모링딩동',
    ori_price=33000,
    discount_price=9900,
    discount_percent=70
    where product_code = '215673141'
''' 
cursor.execute(sql)
rows = cursor.fetchall()

for row in rows:
    print(row)

# 6. DB에 Complete 하기
db.commit()

# 7. DB 연결 닫기
db.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[26], line 22
#      14 cursor = db.cursor()
#      15 sql= '''update product set
#      16     title = '기모링딩동',
#      17     ori_price=33000,
#    (...)
#      20     where product_code = '215673141'
#      21 '''
# ---> 22 cursor.execute(sql)
#      23 rows = cursor.fetchall()
#      25 for row in rows:
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\anaconda3\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (1146, "Table 'ecommerce.product' doesn't exist")

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    if page_num ==0:
        res= requests.get('http://davelee-fun.github.io/')
    else:
        res= requests.get('http://davelee-fun.github.io/page'+ str(page_num+1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.card-body')
    
    for item in data:
        category = item.select_one('h2.card-title').get_text().replace('관련 상품 추천','').strip()
        product = item.select_one('h4.card-text').get_text().replace('상품명:','').strip()
        print(category, product)
# Out:
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 여름이불세트 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 매트리스커버 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 매트리스커버 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 매트리스커버 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 차콜
# 행거도어 WEMAX 다용도 문옷걸이, 화이트, 1개
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 매트리스커버 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 화이트
# 매트리스커버 프랑떼 항균 방수 매트리스커버, 화이트
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 화이트
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# 여름이불세트 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
# 여름이불세트 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
# 여름이불세트 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
# 여름이불세트 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이
# 여름이불세트 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이
# 여름이불세트 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이
# 여름이불세트 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 여름이불세트 아망떼 시어서커 리플 홑이불 패드세트, 허브티
# 여름이불세트 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이
# 여름이불세트 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이
# 여름이불세트 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우
# 여름이불세트 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나
# 여름이불세트 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린
# 여름이불세트 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비
# 여름이불세트 슈에뜨룸 비숑 피치스킨 침구세트, 그레이
# 여름이불세트 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜
# 여름이불세트 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜
# 여름이불세트 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이
# 여름이불세트 예가로드 메리엘 시어서커 누비이불 패드세트, 블루
# 여름이불세트 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트
# 여름이불세트 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린
# 여름이불세트 메종 레이스 차렵 이불 세트, 블루
# 여름이불세트 믹스앤매치 로라 프릴 시어서커 침구세트, 그린
# 여름이불세트 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상
# 여름이불세트 보몽드 메종 레이스 차렵이불 3종 세트, 민트
# 여름이불세트 슈에뜨룸 체크 피치스킨 침구세트, 모카
# 여름이불세트 메리엘 시어서커 에어리플 이불세트, 그레이
# 여름이불세트 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비
# 여름이불세트 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트
# 여름이불세트 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이
# 행거도어 이코디 5단 엔틱 도어 행거, 브라운, 1개
# 행거도어 선우랜드 우드볼 도어훅 4구, 실버, 1개
# 행거도어 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개
# 행거도어 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트
# 행거도어 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개
# 행거도어 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개
# 행거도어 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개
# 행거도어 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트
# 행거도어 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개
# 행거도어 선우랜드 우드볼 도어훅 10구, 실버, 1개
# 행거도어 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개
# 행거도어 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
# 행거도어 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
# 행거도어 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
# 행거도어 [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
# 행거도어 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
# 행거도어 숲속애 웨이브 도어후크 5구, 블랙, 1개
# 행거도어 펀타스틱 다용도 문틀걸이, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 4구, 화이트, 1개
# 행거도어 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
# 행거도어 까사마루 블랑 접이식 문걸이 건조대, 1개
# 행거도어 선우랜드 우드볼 도어훅 6구, 실버, 1개
# 행거도어 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 10구, 화이트, 1개
# 행거도어 코멧 홈 우드볼 도어행거, 6구, 혼합색상
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 행거도어 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
# 행거도어 스파이더락 도어후크 8구, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 6구, 화이트, 1개
# 행거도어 코멧 홈 우드볼 도어행거, 10구, 혼합색상
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키핑크
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 매트리스커버 프로텍트어베드 베이직 매트리스 방수커버, 그레이

# %%
import requests
from bs4 import BeautifulSoup
# 1. 라이브러리 가져오기
import pymysql

# 2. 접속하기
db = pymysql.connect(
    host='localhost', 
    port=3306, 
    user='root', 
    passwd='djaakWkd1!', 
    db='ecommerce', 
    charset='utf8')

# 3. 커서 가져오기
cursor = db.cursor()
 



for page_num in range(10):
    if page_num ==0:
        res= requests.get('http://davelee-fun.github.io/')
    else:
        res= requests.get('http://davelee-fun.github.io/page'+ str(page_num+1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.card-body')
    
    for item in data:
        category = item.select_one('h2.card-title').get_text().replace('관련 상품 추천','').strip()
        product = item.select_one('h4.card-text').get_text().strip()
        print(category, product)
        sql = """insert into teddyproducts (title, category) values('"""+product+"""','"""+category+"""');"""
        print(sql)
        cursor.execute(sql)
        

db.commit()
db.close()
# Out:
# 매트리스커버 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# insert into teddyproducts (title, category) values('상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루','매트리스커버');
# 여름이불세트 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# insert into teddyproducts (title, category) values('상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지','여름이불세트');
# 행거도어 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# insert into teddyproducts (title, category) values('상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조','행거도어');
# 매트리스커버 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# insert into teddyproducts (title, category) values('상품명: 보드래 헬로우 누빔 매트리스커버, 핑크','매트리스커버');
# 매트리스커버 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# insert into teddyproducts (title, category) values('상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜','매트리스커버');
# 매트리스커버 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# insert into teddyproducts (title, category) values('상품명: 피아블 클래식 방수 매트리스커버, 화이트','매트리스커버');
# 매트리스커버 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# insert into teddyproducts (title, category) values('상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이','매트리스커버');
# 매트리스커버 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# insert into teddyproducts (title, category) values('상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이','매트리스커버');
# 매트리스커버 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# insert into teddyproducts (title, category) values('상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이','매트리스커버');
# 매트리스커버 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# insert into teddyproducts (title, category) values('상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이','매트리스커버');
# 매트리스커버 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# insert into teddyproducts (title, category) values('상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리','매트리스커버');
# 매트리스커버 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# insert into teddyproducts (title, category) values('상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜','매트리스커버');
# 행거도어 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# insert into teddyproducts (title, category) values('상품명: WEMAX 다용도 문옷걸이, 화이트, 1개','행거도어');
# 매트리스커버 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# insert into teddyproducts (title, category) values('상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑','매트리스커버');
# 매트리스커버 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# insert into teddyproducts (title, category) values('상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이','매트리스커버');
# 매트리스커버 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# insert into teddyproducts (title, category) values('상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이','매트리스커버');
# 매트리스커버 상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# insert into teddyproducts (title, category) values('상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크','매트리스커버');
# 매트리스커버 상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# insert into teddyproducts (title, category) values('상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜','매트리스커버');
# 매트리스커버 상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트
# insert into teddyproducts (title, category) values('상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트','매트리스커버');
# 매트리스커버 상품명: 프랑떼 항균 방수 매트리스커버, 화이트
# insert into teddyproducts (title, category) values('상품명: 프랑떼 항균 방수 매트리스커버, 화이트','매트리스커버');
# 매트리스커버 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# insert into teddyproducts (title, category) values('상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루','매트리스커버');
# 매트리스커버 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# insert into teddyproducts (title, category) values('상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이','매트리스커버');
# 매트리스커버 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# insert into teddyproducts (title, category) values('상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지','매트리스커버');
# 매트리스커버 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# insert into teddyproducts (title, category) values('상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독','매트리스커버');
# 매트리스커버 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# insert into teddyproducts (title, category) values('상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이','매트리스커버');
# 매트리스커버 상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트
# insert into teddyproducts (title, category) values('상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트','매트리스커버');
# 매트리스커버 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# insert into teddyproducts (title, category) values('상품명: 피아블 클래식 방수 매트리스커버, 화이트','매트리스커버');
# 매트리스커버 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# insert into teddyproducts (title, category) values('상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이','매트리스커버');
# 여름이불세트 상품명: 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
# insert into teddyproducts (title, category) values('상품명: 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크','여름이불세트');
# 여름이불세트 상품명: 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
# insert into teddyproducts (title, category) values('상품명: 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이','여름이불세트');
# 여름이불세트 상품명: 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
# insert into teddyproducts (title, category) values('상품명: 아망떼 시어서커 리플 홑이불 패드세트, 웨이크','여름이불세트');
# 여름이불세트 상품명: 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이
# insert into teddyproducts (title, category) values('상품명: 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이','여름이불세트');
# 여름이불세트 상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이
# insert into teddyproducts (title, category) values('상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이','여름이불세트');
# 여름이불세트 상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이
# insert into teddyproducts (title, category) values('상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이','여름이불세트');
# 여름이불세트 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# insert into teddyproducts (title, category) values('상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지','여름이불세트');
# 여름이불세트 상품명: 아망떼 시어서커 리플 홑이불 패드세트, 허브티
# insert into teddyproducts (title, category) values('상품명: 아망떼 시어서커 리플 홑이불 패드세트, 허브티','여름이불세트');
# 여름이불세트 상품명: 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이
# insert into teddyproducts (title, category) values('상품명: 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이','여름이불세트');
# 여름이불세트 상품명: 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이
# insert into teddyproducts (title, category) values('상품명: 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이','여름이불세트');
# 여름이불세트 상품명: 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우
# insert into teddyproducts (title, category) values('상품명: 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우','여름이불세트');
# 여름이불세트 상품명: 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나
# insert into teddyproducts (title, category) values('상품명: 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나','여름이불세트');
# 여름이불세트 상품명: 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린
# insert into teddyproducts (title, category) values('상품명: 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린','여름이불세트');
# 여름이불세트 상품명: 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비
# insert into teddyproducts (title, category) values('상품명: 바자르 라이닝 혼방 인견 여름 이불베개세트 + 패드 Q, 쿨 네이비','여름이불세트');
# 여름이불세트 상품명: 슈에뜨룸 비숑 피치스킨 침구세트, 그레이
# insert into teddyproducts (title, category) values('상품명: 슈에뜨룸 비숑 피치스킨 침구세트, 그레이','여름이불세트');
# 여름이불세트 상품명: 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜
# insert into teddyproducts (title, category) values('상품명: 스코홈 시어서커 여름 이불 패드 3종 세트, 차콜','여름이불세트');
# 여름이불세트 상품명: 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜
# insert into teddyproducts (title, category) values('상품명: 스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜','여름이불세트');
# 여름이불세트 상품명: 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이
# insert into teddyproducts (title, category) values('상품명: 쉬즈홈 루즈 시어서커 차렵이불 패드세트, 그레이','여름이불세트');
# 여름이불세트 상품명: 예가로드 메리엘 시어서커 누비이불 패드세트, 블루
# insert into teddyproducts (title, category) values('상품명: 예가로드 메리엘 시어서커 누비이불 패드세트, 블루','여름이불세트');
# 여름이불세트 상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트
# insert into teddyproducts (title, category) values('상품명: 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 화이트','여름이불세트');
# 여름이불세트 상품명: 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린
# insert into teddyproducts (title, category) values('상품명: 쉬즈홈 플루 시어서커 차렵이불 패드세트, 그린','여름이불세트');
# 여름이불세트 상품명: 메종 레이스 차렵 이불 세트, 블루
# insert into teddyproducts (title, category) values('상품명: 메종 레이스 차렵 이불 세트, 블루','여름이불세트');
# 여름이불세트 상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그린
# insert into teddyproducts (title, category) values('상품명: 믹스앤매치 로라 프릴 시어서커 침구세트, 그린','여름이불세트');
# 여름이불세트 상품명: 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상
# insert into teddyproducts (title, category) values('상품명: 슈에뜨룸 발그레 피치 리플 침구 세트, 혼합 색상','여름이불세트');
# 여름이불세트 상품명: 보몽드 메종 레이스 차렵이불 3종 세트, 민트
# insert into teddyproducts (title, category) values('상품명: 보몽드 메종 레이스 차렵이불 3종 세트, 민트','여름이불세트');
# 여름이불세트 상품명: 슈에뜨룸 체크 피치스킨 침구세트, 모카
# insert into teddyproducts (title, category) values('상품명: 슈에뜨룸 체크 피치스킨 침구세트, 모카','여름이불세트');
# 여름이불세트 상품명: 메리엘 시어서커 에어리플 이불세트, 그레이
# insert into teddyproducts (title, category) values('상품명: 메리엘 시어서커 에어리플 이불세트, 그레이','여름이불세트');
# 여름이불세트 상품명: 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비
# insert into teddyproducts (title, category) values('상품명: 슈에뜨룸 빠삐용 시어서커 침구세트, 네이비','여름이불세트');
# 여름이불세트 상품명: 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트
# insert into teddyproducts (title, category) values('상품명: 믹스앤매치 에이프릴 리플 누비이불 패드세트, 화이트','여름이불세트');
# 여름이불세트 상품명: 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이
# insert into teddyproducts (title, category) values('상품명: 쉬즈홈 시어서커 홑이불 토퍼세트, 루즈 그레이','여름이불세트');
# 행거도어 상품명: 이코디 5단 엔틱 도어 행거, 브라운, 1개
# insert into teddyproducts (title, category) values('상품명: 이코디 5단 엔틱 도어 행거, 브라운, 1개','행거도어');
# 행거도어 상품명: 선우랜드 우드볼 도어훅 4구, 실버, 1개
# insert into teddyproducts (title, category) values('상품명: 선우랜드 우드볼 도어훅 4구, 실버, 1개','행거도어');
# 행거도어 상품명: 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개
# insert into teddyproducts (title, category) values('상품명: 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개','행거도어');
# 행거도어 상품명: 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트
# insert into teddyproducts (title, category) values('상품명: 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트','행거도어');
# 행거도어 상품명: 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개
# insert into teddyproducts (title, category) values('상품명: 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개','행거도어');
# 행거도어 상품명: 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개
# insert into teddyproducts (title, category) values('상품명: 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개','행거도어');
# 행거도어 상품명: 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개
# insert into teddyproducts (title, category) values('상품명: 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개','행거도어');
# 행거도어 상품명: 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트
# insert into teddyproducts (title, category) values('상품명: 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트','행거도어');
# 행거도어 상품명: 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개
# insert into teddyproducts (title, category) values('상품명: 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개','행거도어');
# 행거도어 상품명: 선우랜드 우드볼 도어훅 10구, 실버, 1개
# insert into teddyproducts (title, category) values('상품명: 선우랜드 우드볼 도어훅 10구, 실버, 1개','행거도어');
# 행거도어 상품명: 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개
# insert into teddyproducts (title, category) values('상품명: 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개','행거도어');
# 행거도어 상품명: 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
# insert into teddyproducts (title, category) values('상품명: 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1','행거도어');
# 행거도어 상품명: 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
# insert into teddyproducts (title, category) values('상품명: 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개','행거도어');
# 행거도어 상품명: 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
# insert into teddyproducts (title, category) values('상품명: 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개','행거도어');
# 행거도어 상품명: [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
# insert into teddyproducts (title, category) values('상품명: [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량','행거도어');
# 행거도어 상품명: 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
# insert into teddyproducts (title, category) values('상품명: 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개','행거도어');
# 행거도어 상품명: 숲속애 웨이브 도어후크 5구, 블랙, 1개
# insert into teddyproducts (title, category) values('상품명: 숲속애 웨이브 도어후크 5구, 블랙, 1개','행거도어');
# 행거도어 상품명: 펀타스틱 다용도 문틀걸이, 화이트, 1개
# insert into teddyproducts (title, category) values('상품명: 펀타스틱 다용도 문틀걸이, 화이트, 1개','행거도어');
# 행거도어 상품명: 선우랜드 우드볼 도어훅 4구, 화이트, 1개
# insert into teddyproducts (title, category) values('상품명: 선우랜드 우드볼 도어훅 4구, 화이트, 1개','행거도어');
# 행거도어 상품명: 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
# insert into teddyproducts (title, category) values('상품명: 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개','행거도어');
# 행거도어 상품명: 까사마루 블랑 접이식 문걸이 건조대, 1개
# insert into teddyproducts (title, category) values('상품명: 까사마루 블랑 접이식 문걸이 건조대, 1개','행거도어');
# 행거도어 상품명: 선우랜드 우드볼 도어훅 6구, 실버, 1개
# insert into teddyproducts (title, category) values('상품명: 선우랜드 우드볼 도어훅 6구, 실버, 1개','행거도어');
# 행거도어 상품명: 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
# insert into teddyproducts (title, category) values('상품명: 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개','행거도어');
# 행거도어 상품명: 선우랜드 우드볼 도어훅 10구, 화이트, 1개
# insert into teddyproducts (title, category) values('상품명: 선우랜드 우드볼 도어훅 10구, 화이트, 1개','행거도어');
# 행거도어 상품명: 코멧 홈 우드볼 도어행거, 6구, 혼합색상
# insert into teddyproducts (title, category) values('상품명: 코멧 홈 우드볼 도어행거, 6구, 혼합색상','행거도어');
# 행거도어 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# insert into teddyproducts (title, category) values('상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조','행거도어');
# 행거도어 상품명: 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
# insert into teddyproducts (title, category) values('상품명: 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개','행거도어');
# 행거도어 상품명: 스파이더락 도어후크 8구, 화이트, 1개
# insert into teddyproducts (title, category) values('상품명: 스파이더락 도어후크 8구, 화이트, 1개','행거도어');
# 행거도어 상품명: 선우랜드 우드볼 도어훅 6구, 화이트, 1개
# insert into teddyproducts (title, category) values('상품명: 선우랜드 우드볼 도어훅 6구, 화이트, 1개','행거도어');
# 행거도어 상품명: 코멧 홈 우드볼 도어행거, 10구, 혼합색상
# insert into teddyproducts (title, category) values('상품명: 코멧 홈 우드볼 도어행거, 10구, 혼합색상','행거도어');
# 매트리스커버 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# insert into teddyproducts (title, category) values('상품명: 보드래 헬로우 누빔 매트리스커버, 핑크','매트리스커버');
# 매트리스커버 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
# insert into teddyproducts (title, category) values('상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리','매트리스커버');
# 매트리스커버 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키핑크
# insert into teddyproducts (title, category) values('상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키핑크','매트리스커버');
# 매트리스커버 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
# insert into teddyproducts (title, category) values('상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고','매트리스커버');
# 매트리스커버 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# insert into teddyproducts (title, category) values('상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이','매트리스커버');
# 매트리스커버 상품명: 프로텍트어베드 베이직 매트리스 방수커버, 그레이
# insert into teddyproducts (title, category) values('상품명: 프로텍트어베드 베이직 매트리스 방수커버, 그레이','매트리스커버');

# %%
import requests
from bs4 import BeautifulSoup
# 1. 라이브러리 가져오기
import pymysql

# 2. 접속하기
db = pymysql.connect(
    host='localhost', 
    port=3306, 
    user='root', 
    passwd='djaakWkd1!', 
    db='ecommerce', 
    charset='utf8')

# 3. 커서 가져오기
cursor = db.cursor()
sql =  'select category, count(*) from teddyproducts group by category'
cursor.execute(sql)
rows = cursor.fetchall()

for row in rows:
    print(row)

db.commit()
db.close()
# Out:
# ('여름이불세트', 31)
# ('행거도어', 32)
# ('매트리스커버', 30)
